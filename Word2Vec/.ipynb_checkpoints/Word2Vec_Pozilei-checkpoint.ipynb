# %%
import pandas as pd
import numpy as np
import json
import spacy
from spacy.lang.de import German
from spacy.lang.de.stop_words import STOP_WORDS
import string
import re
import collections

# %%
#Load Data from JSON into Pandas Dataframe
filename = 'scraped_data/all_reports_all_years_all_pages.json'
df = pd.read_json('scraped_data/all_reports_all_years_all_pages.json', orient='columns', encoding='utf-8')

#Delete all Rows where there is empty articles (String/NaN))
print("How Many Empty Articles are in the Dataframe? {}".format(len(df["article"][(df['article'].values == '')])))
df['article'].replace('', np.nan, inplace=True)
df.dropna(subset=['article'], inplace=True)
print("After Cleaning the Articles, how many empty are there? {}".format(len(df["article"][(df['article'].values == '')])))

#Drop all unneeded columns that are irrelevant for the Model
columns_to_remove = ['response', 'published', 'bezirk', 'subheads', 'url', 'items']
df_clean = df.drop(columns_to_remove, 1)
df_clean.head(5)
pd.set_option('display.max_colwidth', -1)
# Out:
# How Many Empty Articles are in the Dataframe? 6
# After Cleaning the Articles, how many empty are there? 0

# %%
nlp = spacy.load('de_core_news_sm')
punctuations = string.punctuation
punctuations += "–"
punctuations += "€"
punctuations += '„'
punctuations += '“'

def f(x):
    processed = nlp(x)    
    all_processed_descrip = list()
    for sent in processed.sents:
        processed_description = list()
        #Split Doc into Sentences into Words
        words = [token.text for token in sent]
        #Lemmatize Words
        lemmatized_words = [token.lemma_ for token in sent]
        #Remove punctuation and numbers
        remove_punctuation = [token for token in lemmatized_words if (token not in punctuations and not re.match('\d+', token))]
        #Normalize Data
        normalized = [token.lower() for token in remove_punctuation]
        #Remove Stopwords
        removed_stopwords = [token for token in normalized if token not in STOP_WORDS]
        #append final analyzed sentence to preprocessed:
        processed_description.append(removed_stopwords)
        #collect all processed descriptions to one list:
        all_processed_descrip.append(processed_description)
   
    return all_processed_descrip
    

# preprocessed articles and headlines
processed_articles = df_clean["article"].apply(lambda x: f(x))
processed_headlines = df_clean["headline"].apply(lambda x: f(x))

# %%
#further cleaning:
# done: numbers erased (including time, things like 45-jähriger)
# done: string.punctuation added with Gedankenstrich, €
# done: add Gänsefüsschen (id 4)

# TO DO (alternatives)?:
# Stoppwörter durch 'unknown' ersetzen?
# Uhrzeiten ersetzen?
# berliner orte erkennen? 'berliner strasse' als eins lesen?
# Hundert Euro in 100 € umwandeln dann entfernen? (id 16)

# %%
#add new columns to matrix:
df_clean["processed_articles"] = processed_articles
df_clean["processed_headlines"] = processed_headlines

# %%
#remove unnecessary braces etc.:
df_clean["processed_articles"] = df_clean["processed_articles"].apply(np.ravel)
df_clean["processed_headlines"] = df_clean["processed_headlines"].apply(np.ravel)

#df_clean

# %%
#save results to file:
destination_path = 'processed_data/preprocessed_data.json'
df_clean.to_json(destination_path)

# %% [markdown]
# # Read in the analyzed data from json file
# (skips the above part of pipeline analysis which has been saved to a file)

# %%
#load data new from file to work with it from here:
data = pd.read_json('processed_data/preprocessed_data.json', orient='columns', encoding='utf-8')
#data.sort_index()

# %%
#combine headlines (times 2) with text so we have one column to be analyzed:
def combineTextToBeAnalyzed(processed_headline, processed_article):
    emptyList = []
    emptyList.append(processed_headline)
    emptyList.append(processed_headline)
    return emptyList + processed_article

#create new column:
newCol = data.apply(lambda x: combineTextToBeAnalyzed(x['processed_headlines'], x['processed_articles']), axis=1)

data['combinedText'] = newCol
#data.sort_index()

# %% [markdown]
# ## Shuffle data

# %%
#shuffle data:
shuffled_data = data.sample(frac=1)
shuffled_data
# Out:
#                                                 article  \
# 374   Ein Mann und zwei Kinder wurden bei einem Unfa...
# 9377  In der vergangenen Nacht nahmen Polizeibeamte ...
# 8062  Gestern Nachmittag ereignete sich in Moabit ei...
# 2842  Bei Verkehrsunfällen schwer verletzt: Zwei Fuß...
# 6394  Ein Passant alarmierte heute früh Polizei und ...
# 9346  Ein Passant bemerkte gestern Abend eine verlet...
# 2530  Ein 49-jähriger Mann alarmierte heute Mittag d...
# 7918  Der Polizeiliche Staatsschutz des Landeskrimin...
# 4264  Auch an den Weihnachtsfeiertagen sind Trickbet...
# 2965  Heute Vormittag wurde eine Fußgängerin in Gato...
# 2116  In den gestrigen Mittagsstunden wurden Sicherh...
# 4953  Opfer eines Überfalls wurde in der vergangenen...
# 3221  Nach einer Verkehrsunfallflucht vom Samstag, d...
# 383   Gestern Abend gab es in Charlottenburg eine Au...
# 6323  Nach den vorliegenden Ermittlungen kam die 30-...
# 906   Eine Zivilstreife der Autobahnpolizei stoppte ...
# 398   Seit heute Nachmittag arbeitet die Einsatzleit...
# 6463  Zwei Fahrzeuginsassen wurden gestern Abend bei...
# 7162  Gestern Abend überfielen Unbekannte ein Geschä...
# 9432  Gestern Nachmittag nahmen Polizeibeamte im Ort...
# 1050  Drei Schwerverletzte sind die Bilanz eines Ver...
# 1791  Gestern Abend wurde im Spandauer Ortsteil Falk...
# 7397  Am 16. Juli 2014 ist die zentrale Fahrradstaff...
# 1489  Ein Unbekannter hat gestern Abend in Rudow ein...
# 6333  Beamte des Polizeiabschnitts 24 haben in der v...
# 9446  Einen Rauschgifthändler nahmen Beamte des Poli...
# 5777  Unbekannte haben gestern Abend einen Lottolade...
# 3244  Gestern Abend wurden in Gesundbrunnen Polizist...
# 229   Der 83-Jährige, der seit dem 20. September ver...
# 4365  Gestern Abend löste ein durch Ladung zu hoher ...
# ...                                                 ...
# 6488  Polizeibeamte der Direktion 1 haben am vergang...
# 7034  Unbekannte haben gestern Abend einen Geldtrans...
# 3920  In den gestrigen Nachmittagsstunden brach ein ...
# 6708  Ein Mann hatte sich am Dienstag, den 1. Septem...
# 2808  Bei einer Auseinandersetzung vor einem Lokal i...
# 7520  Gestern Abend überfiel eine Gruppe von jungen ...
# 7687  Nachdem ein Mann heute früh in Marzahn den Die...
# 7833  Bei einem Verkehrsunfall in Charlottenburg wur...
# 8575  Heute Morgen um 9.10 Uhr wurde in Wilhelmstadt...
# 659   Zu einer Sachbeschädigung durch Feuer in Fried...
# 5005  Ein Mitarbeiter eines Sicherheitsdienstes alar...
# 234   Am Rande von mehreren Kundgebungen in Friedric...
# 3963  Ein Junge kam gestern Nachmittag nach einem Ve...
# 992   Derzeit unklar ist die Ursache eines Wohnungsb...
# 3783  Unbekannte haben gestern Abend in Lichtenrade ...
# 5307  Zivilpolizisten nahmen in der vergangenen Nach...
# 3957  Gestern Nachmittag kam es in Wedding zu einem ...
# 736   Anwohner riefen in der vergangenen Nacht die P...
# 3721  In einem gemeinsam geführten Ermittlungsverfah...
# 7713  Ermittler des Landeskriminalamtes Berlin und P...
# 7937  Gestern Nachmittag gegen 15.30 Uhr, entdeckten...
# 8427  Ein 64-jähriger Kongolese wurde vergangene Nac...
# 3461  Ein Verkehrsunfall, bei dem ein Kind schwer ve...
# 956   In der vergangenen Nacht brannten zwei Autos i...
# 1867  Mit einer Schusswaffe überfiel heute Vormittag...
# 38    Rund 1.100 Einsatzkräfte waren gestern rund um...
# 1905  Die 91-jährige Rollstuhlfahrerin, die bei eine...
# 4283  In der Nacht setzte ein Unbekannter ein Auto i...
# 6104  Gestern Nachmittag stoppten Polizisten einen A...
# 9620  Der Tourist war auf der Suche nach einer Disko...
#
#                                                headline  \
# 374                           Drei Verletzte bei Unfall
# 9377     Betrunkener mutmaßlicher Autodieb festgenommen
# 8062    Zusammenstoß zwischen Polizeiwagen und Motorrad
# 2842               Bei Verkehrsunfällen schwer verletzt
# 6394                                       Auto brannte
# 9346                                   Seniorin beraubt
# 2530          Fußgänger und Radfahrer geraten in Streit
# 7918          Sachbeschädigungen mit politischem Inhalt
# 4264          Trickbetrüger „arbeiten“ auch Weihnachten
# 2965         Fußgängerin angefahren und schwer verletzt
# 2116              Kontrolleure attackiert und beleidigt
# 4953                Tankstellenmitarbeiterin überfallen
# 3221  Blutend vom Unfallort geflüchtet - Verkehrsunf...
# 383            Auseinandersetzung mit mehreren Personen
# 6323                   Handtaschenraub Potsdamer Straße
# 906                                 Deutlich zu schnell
# 398   Einsatzleitzentrale arbeitet wieder vom Platz ...
# 6463                       Verletzte bei Verkehrsunfall
# 7162                                Geschäft überfallen
# 9432               Festnahme nach versuchtem Enkeltrick
# 1050         Mehrere Schwerverletzte bei Verkehrsunfall
# 1791                     Festnahme nach versuchtem Raub
# 7397  Fahrradstaffel der Polizei Berlin - Erste Erge...
# 1489                              Tankstelle überfallen
# 6333  Mutmaßliche Einbrecher auf der Flucht festgeno...
# 9446                     Rauschgifthändler festgenommen
# 5777                              Lottoladen ausgeraubt
# 3244                             Polizisten angegriffen
# 229                   Vermisster Senior tot aufgefunden
# 4365                           Höhenkontrolle ausgelöst
# ...                                                 ...
# 6488  Tatverdächtiger nach versuchtem Raub festgenom...
# 7034                         Geldtransporter überfallen
# 3920                               Verletzter bei Brand
# 6708             Einbrecher Kulmer Straße in Schöneberg
# 2808           Mit Bierflaschen auf den Kopf geschlagen
# 7520                                 Bordell überfallen
# 7687  Gestohlenes Fahrzeug entdeckt – Tatverdächtige...
# 7833                              Kind von Auto erfasst
# 8575    Kollision mit LKW – schwer verletzter Radfahrer
# 659   Gegenstände auf Fahrbahn angezündet – Staatssc...
# 5005  Versuchte Brandstiftung auf Bundesagentur für ...
# 234   Polizeieinsatz anlässlich mehrerer Kundgebunge...
# 3963              Offenbar bei Rot die Straße überquert
# 992   Mieter bei Wohnungsbrand lebensgefährlich verl...
# 3783                            Überfall auf Supermarkt
# 5307              Mutmaßliche Einbrecherin festgenommen
# 3957                        Schwer verletzter Radfahrer
# 736       Polizeieinsatz nach nicht angemeldetem Aufzug
# 3721  Drogen und mutmaßlicher Handelserlös beschlagn...
# 7713  Festnahme mutmaßlicher Goldhändler nach Anlage...
# 7937     Mauerstück beschmiert – Staatsschutz ermittelt
# 8427                 Afrikaner geschlagen und beleidigt
# 3461                    Kind bei Unfall schwer verletzt
# 956                                     Brennende Autos
# 1867                       Raubüberfall mit Schusswaffe
# 38                      Polizeieinsatz bei Fußballderby
# 1905  Nach Verkehrsunfall - Rollstuhlfahrerin versto...
# 4283                          Brandstiftung an Fahrzeug
# 6104          Festnahme nach mehreren Verkehrsverstößen
# 9620                     Schwerer Raub - Görlitzer Park
#
#                                      processed_articles  \
# 374   [[mann, kind, unfall, gestern, abend, buch, ve...
# 9377  [[vergangen, nacht, nehmen, polizeibeamte, aut...
# 8062  [[gestern, nachmittag, ereignen, moabit, verke...
# 2842  [[verkehrsunfällen, schwer, verletzen], [fußgä...
# 6394  [[passant, alarmieren, früh, polizei, feuerweh...
# 9346  [[passant, bemerken, gestern, abend, verletzen...
# 2530  [[mann, alarmieren, mittag, polizei, imbiss, a...
# 7918  [[polizeiliche, staatsschutz, landeskriminalam...
# 4264  [[weihnachtsfeiertagen, trickbetrüger, aktiv],...
# 2965  [[vormittag, fußgängerin, gatow, verkehrsunfal...
# 2116  [[gestrig, mittagsstunden, sicherheitsmitarbei...
# 4953  [[opfer, überfalls, vergangen, nacht, angestel...
# 3221  [[verkehrsunfallflucht, samstag, august, neukö...
# 383   [[gestern, abend, geben, charlottenburg, ausei...
# 6323  [[vorliegend, ermittlung, samstagabend], [], [...
# 906   [[zivilstreife, autobahnpolizei, stoppen, gest...
# 398   [[nachmittag, arbeiten, einsatzleitzentrale, t...
# 6463  [[fahrzeuginsassen, gestern, abend, verkehrsun...
# 7162  [[gestern, abend, überfallen, unbekannte, gesc...
# 9432  [[gestern, nachmittag, nehmen, polizeibeamte, ...
# 1050  [[schwerverletzte, bilanz, verkehrsunfalls, ge...
# 1791  [[gestern, abend, spandauer, ortsteil, falkenh...
# 7397  [[juli, zentrale, fahrradstaffel, polizei, ber...
# 1489  [[unbekannter, gestern, abend, rudow, tankstel...
# 6333  [[beamte, polizeiabschnitts, vergangen, nacht,...
# 9446  [[rauschgifthändler, nehmen, beamte, polizeiab...
# 5777  [[unbekannte, gestern, abend, lottoladen, marz...
# 3244  [[gestern, abend, gesundbrunnen, polizist, ein...
# 229   [[september, vermisst, tot], [spaziergängerinn...
# 4365  [[gestern, abend, lösen, ladung, lastwagen, hö...
# ...                                                 ...
# 6488  [[polizeibeamte, direktion, vergangen, diensta...
# 7034  [[unbekannte, gestern, abend, geldtransporter,...
# 3920  [[gestrig, nachmittagsstunden, brechen, feuer,...
# 6708  [[mann, dienstag, september, zutritt, wohnung,...
# 2808  [[auseinandersetzung, lokal, wedding, erleiden...
# 7520  [[gestern, abend, überfallen, gruppe, jung, ma...
# 7687  [[mann, früh, marzahn, diebstahl, mercedes, sp...
# 7833  [[verkehrsunfall, charlottenburg, gestern, abe...
# 8575  [[wilhelmstadt, radfahrer, zusammenstoß, lkw, ...
# 659   [[sachbeschädigung, feuer, friedrichshain, erm...
# 5005  [[mitarbeiter, sicherheitsdienstes, alarmieren...
# 234   [[rand, mehrer, kundgebung, friedrichshain, ge...
# 3963  [[junge, gestern, nachmittag, verkehrsunfall, ...
# 992   [[derzeit, unklar, ursache, wohnungsbrandes, g...
# 3783  [[unbekannte, gestern, abend, lichtenrade, leb...
# 5307  [[zivilpolizisten, nehmen, vergangen, nacht, m...
# 3957  [[gestern, nachmittag, wedding, verkehrsunfall...
# 736   [[anwohner, rufen, vergangen, nacht, polizei, ...
# 3721  [[gemeinsam, geführt, ermittlungsverfahren, st...
# 7713  [[ermittler, landeskriminalamtes, berlin, poli...
# 7937  [[gestern, nachmittag, entdecken, zeuge, east,...
# 8427  [[kongolese, vergangen, nacht, angabe, zufolge...
# 3461  [[verkehrsunfall, kind, schwer, verletzen, ere...
# 956   [[vergangen, nacht, brennen, auto, tempelhof],...
# 1867  [[schusswaffe, überfallen, vormittag, unbekann...
# 38    [[einsatzkräfte, gestern, fußballspiel, fc, un...
# 1905  [[rollstuhlfahrerin, verkehrsunfall, august, r...
# 4283  [[nacht, setzen, unbekannter, auto, wedding, b...
# 6104  [[gestern, nachmittag, stoppen, polizist, auto...
# 9620  [[tourist, suche, diskothek, kottbusser, tor, ...
#
#                                     processed_headlines  \
# 374                                  [verletzt, unfall]
# 9377    [betrunkener, mutmaßlich, autodieb, festnehmen]
# 8062             [zusammenstoß, polizeiwagen, motorrad]
# 2842              [verkehrsunfällen, schwer, verletzen]
# 6394                                    [auto, brennen]
# 9346                               [seniorin, berauben]
# 2530            [fußgänger, radfahrer, geraten, streit]
# 7918              [sachbeschädigung, politisch, inhalt]
# 4264             [trickbetrüger, arbeiten, weihnachten]
# 2965         [fußgängerin, anfahren, schwer, verletzen]
# 2116            [kontrolleure, attackieren, beleidigen]
# 4953             [tankstellenmitarbeiterin, überfallen]
# 3221  [blutend, unfallort, flüchten, verkehrsunfallz...
# 383                [auseinandersetzung, mehrer, person]
# 6323           [[handtaschenraub], [potsdamer, straße]]
# 906                               [deutlich, schnellen]
# 398   [einsatzleitzentrale, arbeiten, platz, luftbrü...
# 6463                         [verletzt, verkehrsunfall]
# 7162                             [geschäft, überfallen]
# 9432                  [festnahme, versucht, enkeltrick]
# 1050          [mehrer, schwerverletzte, verkehrsunfall]
# 1791                        [festnahme, versucht, raub]
# 7397        [fahrradstaffel, polizei, berlin, ergebnis]
# 1489                           [tankstelle, überfallen]
# 6333      [mutmaßliche, einbrecher, flucht, festnehmen]
# 9446                    [rauschgifthändler, festnehmen]
# 5777                            [lottoladen, ausrauben]
# 3244                              [polizist, angreifen]
# 229                [vermisster, senior, tot, auffinden]
# 4365                         [höhenkontrolle, auslösen]
# ...                                                 ...
# 6488  [tatverdächtiger, versucht, raub, festnehmen, ...
# 7034                      [geldtransporter, überfallen]
# 3920                                [verletzter, brand]
# 6708           [einbrecher, kulmer, straße, schöneberg]
# 2808                     [bierflaschen, kopf, schlagen]
# 7520                              [bordell, überfallen]
# 7687  [gestohlenes, fahrzeug, entdecken, tatverdächt...
# 7833                              [kind, auto, erfasst]
# 8575      [kollision, lkw, schwer, verletzt, radfahrer]
# 659   [gegenstand, fahrbahn, anzünden, staatsschutz,...
# 5005   [versucht, brandstiftung, bundesagentur, arbeit]
# 234   [polizeieinsatz, anlässlich, mehrer, kundgebun...
# 3963                [offenbar, rot, straße, überqueren]
# 992   [mieter, wohnungsbrand, lebensgefährlich, verl...
# 3783                             [überfall, supermarkt]
# 5307            [mutmaßliche, einbrecherin, festnehmen]
# 3957                      [schwer, verletzt, radfahrer]
# 736                [polizeieinsatz, angemeldet, aufzug]
# 3721  [droge, mutmaßlich, handelserlös, beschlagnahm...
# 7713  [festnahme, mutmaßlich, goldhändler, anlagebet...
# 7937  [mauerstück, beschmieren, staatsschutz, ermitt...
# 8427                  [afrikaner, schlagen, beleidigen]
# 3461                  [kind, unfall, schwer, verletzen]
# 956                                   [brennende, auto]
# 1867                        [raubüberfall, schusswaffe]
# 38                       [polizeieinsatz, fußballderby]
# 1905    [verkehrsunfall, rollstuhlfahrerin, versterben]
# 4283                          [brandstiftung, fahrzeug]
# 6104             [festnahme, mehrer, verkehrsverstößen]
# 9620                  [schwerer, raub, görlitzer, park]
#
#                                            combinedText
# 374   [[verletzt, unfall], [verletzt, unfall], [mann...
# 9377  [[betrunkener, mutmaßlich, autodieb, festnehme...
# 8062  [[zusammenstoß, polizeiwagen, motorrad], [zusa...
# 2842  [[verkehrsunfällen, schwer, verletzen], [verke...
# 6394  [[auto, brennen], [auto, brennen], [passant, a...
# 9346  [[seniorin, berauben], [seniorin, berauben], [...
# 2530  [[fußgänger, radfahrer, geraten, streit], [fuß...
# 7918  [[sachbeschädigung, politisch, inhalt], [sachb...
# 4264  [[trickbetrüger, arbeiten, weihnachten], [tric...
# 2965  [[fußgängerin, anfahren, schwer, verletzen], [...
# 2116  [[kontrolleure, attackieren, beleidigen], [kon...
# 4953  [[tankstellenmitarbeiterin, überfallen], [tank...
# 3221  [[blutend, unfallort, flüchten, verkehrsunfall...
# 383   [[auseinandersetzung, mehrer, person], [ausein...
# 6323  [[[handtaschenraub], [potsdamer, straße]], [[h...
# 906   [[deutlich, schnellen], [deutlich, schnellen],...
# 398   [[einsatzleitzentrale, arbeiten, platz, luftbr...
# 6463  [[verletzt, verkehrsunfall], [verletzt, verkeh...
# 7162  [[geschäft, überfallen], [geschäft, überfallen...
# 9432  [[festnahme, versucht, enkeltrick], [festnahme...
# 1050  [[mehrer, schwerverletzte, verkehrsunfall], [m...
# 1791  [[festnahme, versucht, raub], [festnahme, vers...
# 7397  [[fahrradstaffel, polizei, berlin, ergebnis], ...
# 1489  [[tankstelle, überfallen], [tankstelle, überfa...
# 6333  [[mutmaßliche, einbrecher, flucht, festnehmen]...
# 9446  [[rauschgifthändler, festnehmen], [rauschgifth...
# 5777  [[lottoladen, ausrauben], [lottoladen, ausraub...
# 3244  [[polizist, angreifen], [polizist, angreifen],...
# 229   [[vermisster, senior, tot, auffinden], [vermis...
# 4365  [[höhenkontrolle, auslösen], [höhenkontrolle, ...
# ...                                                 ...
# 6488  [[tatverdächtiger, versucht, raub, festnehmen,...
# 7034  [[geldtransporter, überfallen], [geldtransport...
# 3920  [[verletzter, brand], [verletzter, brand], [ge...
# 6708  [[einbrecher, kulmer, straße, schöneberg], [ei...
# 2808  [[bierflaschen, kopf, schlagen], [bierflaschen...
# 7520  [[bordell, überfallen], [bordell, überfallen],...
# 7687  [[gestohlenes, fahrzeug, entdecken, tatverdäch...
# 7833  [[kind, auto, erfasst], [kind, auto, erfasst],...
# 8575  [[kollision, lkw, schwer, verletzt, radfahrer]...
# 659   [[gegenstand, fahrbahn, anzünden, staatsschutz...
# 5005  [[versucht, brandstiftung, bundesagentur, arbe...
# 234   [[polizeieinsatz, anlässlich, mehrer, kundgebu...
# 3963  [[offenbar, rot, straße, überqueren], [offenba...
# 992   [[mieter, wohnungsbrand, lebensgefährlich, ver...
# 3783  [[überfall, supermarkt], [überfall, supermarkt...
# 5307  [[mutmaßliche, einbrecherin, festnehmen], [mut...
# 3957  [[schwer, verletzt, radfahrer], [schwer, verle...
# 736   [[polizeieinsatz, angemeldet, aufzug], [polize...
# 3721  [[droge, mutmaßlich, handelserlös, beschlagnah...
# 7713  [[festnahme, mutmaßlich, goldhändler, anlagebe...
# 7937  [[mauerstück, beschmieren, staatsschutz, ermit...
# 8427  [[afrikaner, schlagen, beleidigen], [afrikaner...
# 3461  [[kind, unfall, schwer, verletzen], [kind, unf...
# 956   [[brennende, auto], [brennende, auto], [vergan...
# 1867  [[raubüberfall, schusswaffe], [raubüberfall, s...
# 38    [[polizeieinsatz, fußballderby], [polizeieinsa...
# 1905  [[verkehrsunfall, rollstuhlfahrerin, versterbe...
# 4283  [[brandstiftung, fahrzeug], [brandstiftung, fa...
# 6104  [[festnahme, mehrer, verkehrsverstößen], [fest...
# 9620  [[schwerer, raub, görlitzer, park], [schwerer,...
#
# [9924 rows x 5 columns]

# %% [markdown]
# ## Indexierung der Wörter; Erstellen von Lookup-Tables
#
# Nachbau der Ursprungssätze mit neuen Wort-Indizes; Gesamtanzahl der einzigartigen Wörter nötig

# %%
column_vals = data['combinedText'].values
#column_vals

# %%
#remove duplicates from a list of words to get a unique word corpus:
def remove_duplicates(li):
    set_of_words = []
    for word in li:
       if word not in set_of_words:
          set_of_words.append(word)
    return set_of_words

# %%
def count_words(words):
    dict = {}
    for word in words:
        if word not in dict:
            dict[word] = 1
        else:
            dict[word] += 1
    return dict

# %%
def get_descending_list_of_most_common_words(words):
    unique_words = count_words(words)
    return {k: v for k, v in sorted(unique_words.items(), key=lambda item: item[1], reverse=True)}

# %%
#example:
woerter = ['hallo', 'hallo', 'tada', 'bald', 'tada', 'hallo', 'hallo']
res = get_descending_list_of_most_common_words(woerter)
res
# Out:
# {'hallo': 4, 'tada': 2, 'bald': 1}

# %%
sentences = [sent for pd_list in column_vals for sent in pd_list]
words = [word for sent in sentences for word in sent]


#vocabulary_size=None
if not vocabulary_size:
    unique_words = remove_duplicates(words)
    vocabulary_size = len(unique_words)


words_len = len(words)
print(words_len)
print(vocabulary_size)

#words
# Out:
# 605936
# 605303

# %%
def build_lookup_tables(docs, vocabulary_size=None):
    '''
    :param docs: Spalte eines pandas-DF: data['preprocessed'].values
    :return sentences: Alle Sätze aller Dokumente in einer Liste
    :return words: Alle Wörter aller Dokumente in einer Liste
    :return word_count: Häufigkeiten der jeweiligen Wörter in allen Dokumenten
    :return word_2_index_dict: Lookup-Table
    :return index_2_word_dict: Lookup-Table
    :return sentences_as_index: Alle Sätze aller Dokumente mit Wortindex, anstatt des Wortes
    :return sentences_as_index_flattened: wie sentences_as_index, aber ohne subarrays (flattened)
    :return vocabulary_size: Anzahl der einzigartigen Wörter
    '''
    sentences = [sent for pd_list in docs for sent in pd_list]
    words = [word for sent in sentences for word in sent]
  
    if not vocabulary_size:
        # Anzahl der einzigartigen Wörter
        unique_words = remove_duplicates(words)
        vocabulary_size = len(unique_words)
 
    # Anzahl der Worthäufigkeiten
    #word_count = collections.Counter(words).most_common(vocabulary_size) #vonbasti
    #basti hatte word_count vom typ list, wir haben ein dict gerade(!)
    word_count = get_descending_list_of_most_common_words(words)
    #brauchen wir die folgende zeile überhaupt?
    #word_count.append(['UNK', -1]) # Flag für Wörter, die nicht oft vorkommen (nur wichtig bei begrenzter Vokabulargröße)
  
    # Lookup-Tables
    word_2_index_dict = {}
    for index, word in enumerate(word_count):
        word_2_index_dict[word[0]] = index
  
    index_2_word_dict = dict(zip(word_2_index_dict.values(), word_2_index_dict.keys()))
  
    # Wörter der Anfragetexte durch Indizes austauschen:
    sentences_as_index = []
    unknown_word_count = 0
    for sent in sentences:
        sent_index = []
        for word in sent:
            if word in word_2_index_dict:
                sent_index.append(word_2_index_dict[word])
            else:
                unknown_word_count += 1
        if sent_index:
            sentences_as_index.append(sent_index)
    word_count[-1][1] = unknown_word_count

    sentences_as_index_flattened = [word for sent in sentences_as_index for word in sent]
  
    return sentences, words, word_count, word_2_index_dict, index_2_word_dict, sentences_as_ind

# %%
 #sentences, words, word_count, word_2_index_dict, index_2_word_dict, sentences_as_index, sentences_as_index_flattened, vocabulary_size = build_lookup_tables(data['combinedText'].values)
